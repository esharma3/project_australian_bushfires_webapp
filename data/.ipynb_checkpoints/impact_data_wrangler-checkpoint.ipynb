# %%
import pandas as pd
import warnings
import pymysql

# %%
df = pd.read_csv("protected_species_impact.csv").fillna('N/A').rename(
    columns = {"Percentage of the species modelled likely and known distribution within fire affected areas": "Afected Area", 
               "EPBC Act listed Threatened Status": "Protected Status", 
               "EPBC Act listed Migratory Status": "Migratory Status", 
               "Range states and territories": "Location"}
)
df.head()
# Out:
#           Scientific Name                                   Common Name  \
# 0      Acacia awestoniana                         Stirling Range Wattle
# 1       Acacia constablei                             Narrabarba Wattle
# 2  Andersonia axilliflora                              Giant Andersonia
# 3          Baeckea kandos                                       a shrub
# 4     Bertmainius colonus  Eastern Stirling Range Pygmy Trapdoor Spider
#
#   Afected Area    Type Protected Status Migratory Status Location
# 0         ≥80%   Plant       Vulnerable                0       WA
# 1         ≥80%   Plant       Vulnerable                0      NSW
# 2         ≥80%   Plant       Endangered                0       WA
# 3         ≥80%   Plant       Endangered                0      NSW
# 4         ≥80%  Spider       Vulnerable                0       WA

# %% [markdown]
# ### SQL DB STUFF

# %%
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

USER = "root"
PASSWORD = "sqlJD@C20199661"
HOST = "127.0.0.1"
PORT = "3306"
DATABASE = "bushfires_db"
TABLENAME = "impact_archives"

engine = create_engine(f"mysql+pymysql://{USER}:{PASSWORD}@{HOST}:{PORT}")

try:
    engine.execute(f"CREATE DATABASE {DATABASE}")
except ProgrammingError:
    warnings.warn(
        f"Could not create database {DATABASE}. Database {DATABASE} may already exist."
    )
    pass

engine.execute(f"USE {DATABASE}")
engine.execute(f"DROP TABLE IF EXISTS {TABLENAME}")

df.to_sql(name = TABLENAME, con = engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/.local/share/virtualenvs/project_data_jobs_market_analysis-jqenum20/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~/.local/share/virtualenvs/project_data_jobs_market_analysis-jqenum20/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ...

# %%
impact_archives = pd.read_sql("SELECT * FROM bushfires_db.impact_archives", engine)
data_jobs_sql_table.head(2)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/share/virtualenvs/project_data_jobs_market_analysis-jqenum20/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~/.local/share/virtualenvs/project_data_jobs_market_analysis-jqenum20/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~/.local/share/virtualenvs/project_data_jobs_market_analysis-jqenum20/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ...
